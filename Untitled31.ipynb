# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url=("https://www.pakwheels.com/used-bikes/search/-/")
p=requests.get(url)
htmlcontent=p.content
soup=BeautifulSoup(htmlcontent,'html.parser')
soup
# Out:
# <div class="modal" id="safety_precautions">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header noborder pb0">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# </div>
# <div class="modal-body nomargin" style="padding: 0px 40px 10px;">
# <div class="tlc mb25">
# <img alt="Tips-for-safe-deal" height="70px" src="https://wsa4.pakwheels.com/assets/tips-for-safe-deal-00805d1034ee7600820049c852bd6163.svg"/>
# <div class="mb0 fs18 generic-basic mt10 lhm fwm">Tips for Safe Deal</div>
# </div>
# <div class="d-flex align-center mb15">
# <img alt="Tip-for-safe-deal-1" class="mr20" height="36px" src="https://wsa1.pakwheels.com/assets/tip-for-safe-deal-1-a3f472bbbc5249edca9fd01f449f98c3.svg"/>
# <p class="fs16 nomargin">Never make payments in advance.</p>
# </div>
# <div class="d-flex align-center mb15">
# ...

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <div class="modal" id="safety_precautions">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header noborder pb0">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# </div>
# <div class="modal-body nomargin" style="padding: 0px 40px 10px;">
# <div class="tlc mb25">
# <img alt="Tips-for-safe-deal" height="70px" src="https://wsa4.pakwheels.com/assets/tips-for-safe-deal-00805d1034ee7600820049c852bd6163.svg"/>
# <div class="mb0 fs18 generic-basic mt10 lhm fwm">Tips for Safe Deal</div>
# </div>
# <div class="d-flex align-center mb15">
# <img alt="Tip-for-safe-deal-1" class="mr20" height="36px" src="https://wsa1.pakwheels.com/assets/tip-for-safe-deal-1-a3f472bbbc5249edca9fd01f449f98c3.svg"/>
# <p class="fs16 nomargin">Never make payments in advance.</p>
# </div>
# <div class="d-flex align-center mb15">
# ...

# %%
df=pd
row1=soup.find_all('strong',class_='generic-white fs18')
price = []
for p in row1:
    price.append(p.text)
price
# Out:
# ['PKR 385,000  ',
#  'PKR 98,000  ',
#  'PKR 150,000  ',
#  'PKR 620,000  ',
#  'PKR 300,000  ',
#  'PKR 2,275,000  ',
#  'PKR 82,500  ',
#  'PKR 25,000  ',
#  'Call for price  ',
#  'PKR 155,000  ',
#  'PKR 2,250,000  ',
#  'PKR 2,250,000  ',
#  'PKR 165,000  ',
#  'PKR 63,000  ',
#  'PKR 97,000  ',
#  'PKR 150,000  ',
#  'PKR 42,500  ',
#  'PKR 160,000  ',
#  'PKR 99,000  ',
#  'PKR 270,000  ',
#  'PKR 116,000  ',
#  'PKR 400,000  ',
#  'PKR 90,000  ',
#  'PKR 150,000  ',
#  'PKR 150,000  ',
#  'PKR 42,500  ',
#  'PKR 165,000  ',
#  'PKR 165,000  ',
#  'PKR 209,500  ',
#  'PKR 110,000  ',
#  'PKR 107,000  ',
#  'PKR 195,000  ',
#  'PKR 155,000  ',
#  'PKR 815,000  ',
#  'PKR 285,000  ',
#  'PKR 235,000  ']

# %%
row2=soup.find_all('div',class_='search-title')
title = []
for n in row2:
    title.append(n.text.replace('\n',"")[1:-1])
title
# Out:
# ['                       PKR 3.85 lacsSuzuki GR 150  2021  for Sal',
#  '                       PKR 98,000                  Honda CG 125  2020  for Sal',
#  '                       PKR 1.5 lacsHonda CG 125  2021  for Sal',
#  '                       PKR 6.2 lacsChinese Bikes OW R3 400cc  2022  for Sal',
#  '                       PKR 3 lacsHi Speed Infinity 150  2022  for Sal',
#  '                       PKR 22.75 lacsSuzuki GSX-R600  2012  for Sal',
#  '                       PKR 82,500                  Honda CD 70  2019  for Sal',
#  '                       PKR 25,000                  Hi Speed CDI SR-70CC EURO-2  2022  for Sal',
#  '                       Call                  Road Prince Other  2022  for Sal',
#  '                       PKR 1.55 lacsHonda CG 125  2022  for Sal',
#  '                       PKR 22.5 lacsBenelli TNT 600i  2022  for Sal',
#  '                       PKR 22.5 lacsBenelli TNT 600i  2022  for Sal',
# ...

# %%
row3=soup.find_all('div',class_='clearfix')
Sellers_Comments = []
for n in row3:
    Sellers_Comments.append(n.text.replace('\n',""))
Sellers_Comments
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '                                Send Message                                                  Show Phone No.                      2021300 km4 StrokePKR 385,000   2                          \t\tFEATURED    \t                        PKR 3.85 lacsSuzuki GR 150  2021  for Sale                    Lahore                  2021300 km4 StrokeUpdated about 1 hour agoShow Phone No.                    ',
#  '                                Send Message                                                  Show Phone No.                      2021300 km4 StrokePKR 385,000  ',
#  'Updated about 1 hour agoShow Phone No.                    ',
# ...

# %%
df=pd.DataFrame(row1,columns=['price'])
df['title']=row2
df.to_csv('pakwheels.csv')

# %%
read=pd.read_csv
print("Reading data from csv file")
# Out:
# Reading data from csv file

# %%
print(read)
# Out:
# <function read_csv at 0x7f3c3ca29670>

# %%
df.head()
# Out:
#            price                                              title
# 0  PKR 385,000    [\n, [\n, [\n\n                        PKR 3.8...
# 1   PKR 98,000    [\n, [\n, [\n\n                        PKR 98,...
# 2  PKR 150,000    [\n, [\n, [\n\n                        PKR 1.5...
# 3  PKR 620,000    [\n, [\n, [\n\n                        PKR 6.2...
# 4  PKR 300,000    [\n, [\n, [\n\n                        PKR 3 ,...

# %%
df.tail()
# Out:
#             price                                              title
# 31  PKR 195,000    [\n, [\n, [\n\n                        PKR 1.9...
# 32  PKR 155,000    [\n, [\n, [\n\n                        PKR 1.5...
# 33  PKR 815,000    [\n, [\n, [\n\n                        PKR 8.1...
# 34  PKR 285,000    [\n, [\n, [\n\n                        PKR 2.8...
# 35  PKR 235,000    [\n, [\n, [\n\n                        PKR 2.3...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(title,price)
# Out:
# ['                       PKR 3.85 lacsSuzuki GR 150  2021  for Sal', '                       PKR 98,000                  Honda CG 125  2020  for Sal', '                       PKR 1.5 lacsHonda CG 125  2021  for Sal', '                       PKR 6.2 lacsChinese Bikes OW R3 400cc  2022  for Sal', '                       PKR 3 lacsHi Speed Infinity 150  2022  for Sal', '                       PKR 22.75 lacsSuzuki GSX-R600  2012  for Sal', '                       PKR 82,500                  Honda CD 70  2019  for Sal', '                       PKR 25,000                  Hi Speed CDI SR-70CC EURO-2  2022  for Sal', '                       Call                  Road Prince Other  2022  for Sal', '                       PKR 1.55 lacsHonda CG 125  2022  for Sal', '                       PKR 22.5 lacsBenelli TNT 600i  2022  for Sal', '                       PKR 22.5 lacsBenelli TNT 600i  2022  for Sal', '                       PKR 1.65 lacsHonda CG 125  2022  for Sal', '                      
# ...

# %%
df.to_csv('pakwheels.csv', index=False, encoding='utf-8')

# %%
read=pd.read_csv

# %%
df.shape
# Out:
# (36, 2)

# %%
df.dtypes
# Out:
# price    object
# title    object
# dtype: object

# %%
df.isnull()
# Out:
#     price  title
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False
# 20  False  False
# 21  False  False
# 22  False  False
# 23  False  False
# 24  False  False
# 25  False  False
# 26  False  False
# 27  False  False
# 28  False  False
# 29  False  False
# 30  False  False
# 31  False  False
# 32  False  False
# 33  False  False
# 34  False  False
# 35  False  False

# %%
df.isnull().sum()
# Out:
# price    0
# title    0
# dtype: int64

# %%
df['title'].nunique()
# Out:
# 36

# %%
df['price'].value_counts()
# Out:
# PKR 150,000         4
# PKR 165,000         3
# PKR 42,500          2
# PKR 155,000         2
# PKR 2,250,000       2
# PKR 99,000          1
# PKR 285,000         1
# PKR 815,000         1
# PKR 195,000         1
# PKR 107,000         1
# PKR 110,000         1
# PKR 209,500         1
# PKR 90,000          1
# PKR 400,000         1
# PKR 116,000         1
# PKR 270,000         1
# PKR 385,000         1
# PKR 160,000         1
# PKR 98,000          1
# PKR 97,000          1
# PKR 63,000          1
# Call for price      1
# PKR 25,000          1
# PKR 82,500          1
# PKR 2,275,000       1
# PKR 300,000         1
# PKR 620,000         1
# PKR 235,000         1
# Name: price, dtype: int64

# %%
df.describe()
# Out:
#                 price                                              title
# count              36                                                 36
# unique             28                                                 36
# top     PKR 150,000    [\n, [\n, [\n\n                        PKR 3.8...
# freq                4                                                  1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
df.columns
# Out:
# Index(['price', 'title'], dtype='object')

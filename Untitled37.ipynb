# %%
import numpy as np
import pandas as pd
from sklearn import svm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(font_scale = 1.2)

# %%
recipes = pd.read_csv('Cupcakes vs Muffins.csv')

# %%
recipes.head()
# Out:
#      Type  Flour  Milk  Sugar  Butter  Egg  Baking Powder  Vanilla  Salt
# 0  Muffin     55    28      3       7    5              2        0     0
# 1  Muffin     47    24     12       6    9              1        0     0
# 2  Muffin     47    23     18       6    4              1        0     0
# 3  Muffin     45    11     17      17    8              1        0     0
# 4  Muffin     50    25     12       6    5              2        1     0

# %%
sns.histplot(data=recipes, x='Sugar', hue='Type', multiple='stack')

# %%
sns.displot(data=recipes, x='Sugar', hue='Type', col='Type')

# %%
sns.boxplot(x='Flour', hue='Type', data=recipes)
sns.despine(offset=10, trim=True)

# %%
sns.pairplot(recipes, hue='Flour')

# %%
plt.bar(recipes['Type'], recipes['Milk'])
plt.show()

# %%
g = sns.PairGrid(recipes)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(recipes, hue='Flour')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
sns.lineplot(data=recipes.drop(['Milk'], axis=1))
plt.show()

# %%
sns.countplot(x='Flour', data=recipes)
plt.show()

# %%
plt.figure(figsize= (18,8))
plt.style.use('fivethirtyeight')
ax = sns.countplot('Flour', data=recipes, palette='pink')
ax.set_xlabel(xlabel='Different Recepies', fontsize=16)
ax.set_ylabel(ylabel='Recpies food quality', fontsize=16)
ax.set_title(label='Comparison of food and recepies product', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize= (13,8))
ax = sns.countplot('Flour', data=recipes, palette='dark')
ax.set_xlabel(xlabel='Different Recepies', fontsize=16)
ax.set_ylabel(ylabel='Recpies food quality', fontsize=16)
ax.set_title(label='Comparison of food and recepies product', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize= (20,5))
plt.style.use('fivethirtyeight')
ax = sns.distplot(recipes['Milk'], color='blue')
plt.xlabel('Different Recepies', fontsize=16)
plt.ylabel('Recpies food quality', fontsize=16)
plt.title('Comparison of food and recepies product', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.style.use('fivethirtyeight')
recipes['Flour'].value_counts().head(80).plot.bar(color='orange', figsize=(20, 7))
plt.title('differrent foods recepies', fontsize = 20, fontweight = 16)
plt.xlabel('favorite recepie method')
plt.ylabel('recepies docs')
plt.show()

# %%
sns.set(style = "dark", palette = "colorblind", color_codes = True)
x = recipes.Milk
plt.figure(figsize=(15,8))
ax = sns.distplot(x, bins=58, kde=False)
ax.set_xlabel(xlabel='Different Recepies', fontsize=16)
ax.set_ylabel(ylabel='Recpies food quality', fontsize=16)
ax.set_title(label='Comparison of food and recepies product', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot('Flour', 'Sugar', data=recipes, hue='Type')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
type_label = np.where(recipes['Type']=='Muffin', 0,1)
recipe_features = recipes.columns.values[1:].tolist()
recipe_features
ingredients = recipes[recipe_features].values
print(ingredients)
# Out:
# [[55 28  3  7  5  2  0  0]
#  [47 24 12  6  9  1  0  0]
#  [47 23 18  6  4  1  0  0]
#  [45 11 17 17  8  1  0  0]
#  [50 25 12  6  5  2  1  0]
#  [55 27  3  7  5  2  1  0]
#  [54 27  7  5  5  2  0  0]
#  [47 26 10 10  4  1  0  0]
#  [50 17 17  8  6  1  0  0]
#  [50 17 17 11  4  1  0  0]
#  [39  0 26 19 14  1  1  0]
#  [42 21 16 10  8  3  0  0]
#  [34 17 20 20  5  2  1  0]
#  [39 13 17 19 10  1  1  0]
#  [38 15 23 15  8  0  1  0]
#  [42 18 25  9  5  1  0  0]
#  [36 14 21 14 11  2  1  0]
#  [38 15 31  8  6  1  1  0]
#  [36 16 24 12  9  1  1  0]
#  [34 17 23 11 13  0  1  0]]

# %%
model = svm.SVC(kernel='linear')
model.fit(ingredients, type_label)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Initialize the array to store within-cluster sum of squares
wcss = []

# Loop over a range of possible number of clusters
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plot the within-cluster sum of squares
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
